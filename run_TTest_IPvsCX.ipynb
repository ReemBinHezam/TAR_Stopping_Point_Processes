# %% [markdown]
# #Summary Results
# ## Paired T-Test (for AutoTAR ranking on all datasets)
#
#
# From results, the difference between the Inhomogeneous Poisson and Cox
# processe found to be statistically significant (< 0.05) for all measures expet cost.
# In average, the Inhomogeneous Poisson process achieved higher recall and reliability, with less relative error than the Cox process. However, although the Inhomogeneous Poisson process had higher cost than the Cox process, the difference between them were not statistically significiant. Thus Inhomogeneous Poisson process would be selected among the the Cox process.
#
#
# ## Paired T-Test for Multiple Runs (initial sample size/alpha = 0.025)
#
# Below are the T-Test results for all runs (rankings) on CLEF2017 and CLEF2018, from the p-values, we can prove that the mean difference between IP and CX are not statistically significant (> 0.05) for all measures: recall, reliability, cost, loss error , and  rel error.
# So from this observation, and since the CX method is more computationally expensive, we can select IP among CX.

# %%
# MOUNT GOOGLE DRIVE 
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Importing library
import scipy.stats as stats
import pandas as pd
import numpy as np

# %%
#set path
PARENT_DIR = '/content/drive/MyDrive/ReemSharedPhD/SharedCode/TOIS_paper_code/'

# %% [markdown]
# # Load data

# %%
# prepare data for TTest
df_all = pd.read_csv(PARENT_DIR+'TTest/results/df_all_rates_forTTest.csv', index_col=0)
df_all['Model'] = df_all.index
df_all['process_type'] = df_all['Model'].apply(lambda x: 'IP' if any(i in x for i in ['IP']) else 'CX')
df_all = df_all.drop(['Model'], axis=1)
df_all
# Out:
#                         recall   cost  reliability  loss_er  rel_err  \
# CLEF2017_0.95-1.0-IP-P   1.000  0.287        0.967    0.030    0.000
# CLEF2017_0.95-1.0-CX-P   1.000  0.287        0.967    0.030    0.000
# CLEF2017_0.95-1.0-IP-H   0.970  0.213        0.900    0.037    0.030
# CLEF2017_0.95-1.0-CX-H   0.955  0.188        0.800    0.045    0.045
# CLEF2017_0.95-1.0-IP-E   0.999  0.246        0.933    0.026    0.001
# ...                        ...    ...          ...      ...      ...
# Legal_0.95-0.8-CX-H      0.793  0.025        0.500    0.045    0.065
# Legal_0.95-0.8-IP-E      0.793  0.025        0.500    0.045    0.065
# Legal_0.95-0.8-CX-E      0.793  0.025        0.500    0.045    0.065
# Legal_0.95-0.8-IP-A      0.793  0.025        0.500    0.045    0.065
# Legal_0.95-0.8-CX-A      0.793  0.025        0.500    0.045    0.065
#
#                        dataset_name  des_prob  des_recall process_type
# CLEF2017_0.95-1.0-IP-P     CLEF2017      0.95         1.0           IP
# CLEF2017_0.95-1.0-CX-P     CLEF2017      0.95         1.0           CX
# CLEF2017_0.95-1.0-IP-H     CLEF2017      0.95         1.0           IP
# CLEF2017_0.95-1.0-CX-H     CLEF2017      0.95         1.0           CX
# CLEF2017_0.95-1.0-IP-E     CLEF2017      0.95         1.0           IP
# ...                             ...       ...         ...          ...
# Legal_0.95-0.8-CX-H           Legal      0.95         0.8           CX
# Legal_0.95-0.8-IP-E           Legal      0.95         0.8           IP
# Legal_0.95-0.8-CX-E           Legal      0.95         0.8           CX
# Legal_0.95-0.8-IP-A           Legal      0.95         0.8           IP
# Legal_0.95-0.8-CX-A           Legal      0.95         0.8           CX
#
# [120 rows x 9 columns]

# %%
df_all_IP = df_all.loc[df_all['process_type'] == 'IP']
df_all_CX = df_all.loc[df_all['process_type'] == 'CX']

df_all_IP.index.name='Model'
df_all_IP = df_all_IP.reset_index()

df_all_CX.index.name='Model'
df_all_CX = df_all_CX.reset_index()

# %% [markdown]
# ## Paired T-Test (for AutoTAR ranking on all datasets)

# %% [markdown]
# From results, the difference between the Inhomogeneous Poisson and Cox
# processe found to be statistically significant (< 0.05) for all measures expet cost.
# In average, the Inhomogeneous Poisson process achieved higher recall and reliability, with less relative error than the Cox process. However, although the Inhomogeneous Poisson process had higher cost than the Cox process, the difference between them were not statistically significiant. Thus Inhomogeneous Poisson process would be selected among the the Cox process.

# %% [markdown]
# ### T-Test for all target recalls

# %%
eval_measures = ['recall', 'cost', 'reliability', 'loss_er','rel_err']
for eval_measure in eval_measures:
    statistic, pvalue = stats.ttest_rel(df_all_IP[eval_measure], df_all_CX[eval_measure])
    print(f'{eval_measure: <15}: statistic=\t{statistic: <20}\t pvalue= {pvalue}')
# Out:
# recall         : statistic=	2.135531491045044   	 pvalue= 0.036879042887926206
# cost           : statistic=	1.6507736192430298  	 pvalue= 0.10409864211992932
# reliability    : statistic=	2.2304387525771934  	 pvalue= 0.029534597269637586
# loss_er        : statistic=	-2.420539409701707  	 pvalue= 0.018594416271394982
# rel_err        : statistic=	-2.150774670385616  	 pvalue= 0.03560128465813283

# %%
print('IP recall is higher than CX recall with an average: ', np.mean(df_all_IP['recall']- df_all_CX['recall']))
print('IP cost is higher than CX cost with an average: ', np.mean(df_all_IP['cost']- df_all_CX['cost']))
print('IP reliability is higher than CX reliability with an average: ', np.mean(df_all_IP['reliability']- df_all_CX['reliability']))
print('IP loss_er is lower than CX loss_er with an average: ', np.mean(df_all_IP['loss_er']- df_all_CX['loss_er']))
print('IP rel_err is lower than CX rel_err with an average: ', np.mean(df_all_IP['rel_err']- df_all_CX['rel_err']))
# Out:
# IP recall is higher than CX recall with an average:  0.0040833333333333355
# IP cost is higher than CX cost with an average:  0.006516666666666667
# IP reliability is higher than CX reliability with an average:  0.027633333333333333
# IP loss_er is lower than CX loss_er with an average:  -0.0009000000000000001
# IP rel_err is lower than CX rel_err with an average:  -0.0032166666666666667

# %% [markdown]
# ### T-Test for each target recall

# %%
des_recalls = [1.0, 0.9, 0.8]
eval_measures = ['recall', 'cost', 'reliability', 'loss_er','rel_err']
for des_recall in des_recalls:
  for eval_measure in eval_measures:
    statistic, pvalue = stats.ttest_rel(df_all_IP.loc[df_all_IP['des_recall'] == des_recall][eval_measure], df_all_CX.loc[df_all_CX['des_recall'] == des_recall][eval_measure])
    print(f'{des_recall}_{eval_measure: <15}: statistic=\t{statistic: <20}\t pvalue= {pvalue}')
  print('-----------------------------------------------------------------------------------')
    #print(des_recall, eval_measure, stats.ttest_rel(df_all_IP.loc[df_all_IP['des_recall'] == des_recall][eval_measure], df_all_CX.loc[df_all_CX['des_recall'] == des_recall][eval_measure]))
# Out:
# 1.0_recall         : statistic=	1.772164711748817   	 pvalue= 0.09240333467552633
# 1.0_cost           : statistic=	2.297857132507309   	 pvalue= 0.033097581735625416
# 1.0_reliability    : statistic=	2.5151292965263488  	 pvalue= 0.02105732832264171
# 1.0_loss_er        : statistic=	-0.8253937850495404 	 pvalue= 0.4193913722384005
# 1.0_rel_err        : statistic=	-1.7721647117488162 	 pvalue= 0.09240333467552642
# -----------------------------------------------------------------------------------
# 0.9_recall         : statistic=	1.3983105971903038  	 pvalue= 0.17812973666438192
# 0.9_cost           : statistic=	-0.6316434134646026 	 pvalue= 0.5351464359186469
# 0.9_reliability    : statistic=	1.396602596967616   	 pvalue= 0.1786353447307344
# 0.9_loss_er        : statistic=	-2.073829566497507  	 pvalue= 0.0519311935932808
# 0.9_rel_err        : statistic=	-1.7983443922651425 	 pvalue= 0.08803072446440387
# -----------------------------------------------------------------------------------
# 0.8_recall         : statistic=	-0.9335735820102884 	 pvalue= 0.3622373349295994
# 0.8_cost           : statistic=	-1.993738651465908  	 pvalue= 0.06073573708170005
# 0.8_reliability    : statistic=	0.9999999999999998  	 pvalue= 0.32987680092112504
# 0.8_loss_er        : statistic=	-1.5767904662557288 	 pvalue= 0.13134822623405792
# 0.8_rel_err        : statistic=	-1.467384917127609  	 pvalue= 0.15863021078255776
# -----------------------------------------------------------------------------------

# %% [markdown]
# # Load mult runs data for TTest

# %%
DIR_runs = PARENT_DIR+'RunMultipleRankings/' 

df_all_forTTest = pd.read_csv(DIR_runs+'results/all_runs_scores_OR_IP_CX.csv', index_col=0)
df_all_forTTest
# Out:
#            recall         cost  reliability      loss_er      rel_err  \
# OR    0.924±0.000  0.471±0.209  1.000±0.000  0.173±0.115  0.027±0.000
# IP-P  0.923±0.054  0.692±0.117  0.840±0.080  0.299±0.115  0.137±0.040
# IP-H  0.699±0.171  0.307±0.050  0.354±0.200  0.261±0.161  0.284±0.162
# IP-E  0.832±0.066  0.444±0.168  0.549±0.123  0.231±0.131  0.164±0.065
# IP-A  0.759±0.144  0.382±0.069  0.457±0.179  0.252±0.151  0.240±0.140
# CX-P  0.919±0.058  0.681±0.113  0.820±0.097  0.291±0.111  0.135±0.038
# CX-H  0.681±0.186  0.304±0.038  0.352±0.215  0.277±0.165  0.305±0.174
# CX-E  0.839±0.066  0.454±0.168  0.561±0.123  0.232±0.131  0.160±0.065
# CX-A  0.759±0.144  0.382±0.069  0.457±0.179  0.252±0.151  0.240±0.140
# OR    0.912±0.000  0.527±0.261  1.000±0.000  0.154±0.120  0.013±0.000
# IP-P  0.911±0.065  0.684±0.083  0.755±0.165  0.195±0.063  0.127±0.025
# IP-H  0.663±0.136  0.231±0.031  0.245±0.160  0.220±0.096  0.299±0.127
# IP-E  0.769±0.104  0.334±0.087  0.357±0.237  0.156±0.058  0.197±0.083
# IP-A  0.749±0.116  0.339±0.057  0.364±0.188  0.177±0.076  0.232±0.099
# CX-P  0.905±0.069  0.672±0.080  0.712±0.227  0.191±0.062  0.126±0.025
# CX-H  0.649±0.139  0.233±0.025  0.257±0.171  0.239±0.098  0.319±0.128
# CX-E  0.785±0.094  0.353±0.099  0.382±0.248  0.150±0.054  0.181±0.072
# CX-A  0.749±0.116  0.339±0.057  0.364±0.188  0.177±0.076  0.232±0.099
# OR    0.830±0.000  0.356±0.205  1.000±0.000  0.140±0.100  0.038±0.000
# IP-P  0.908±0.067  0.633±0.108  0.872±0.086  0.265±0.108  0.227±0.024
# IP-H  0.683±0.167  0.286±0.052  0.446±0.258  0.261±0.162  0.298±0.136
# IP-E  0.785±0.076  0.382±0.157  0.604±0.177  0.223±0.122  0.215±0.055
# IP-A  0.759±0.144  0.382±0.069  0.601±0.236  0.252±0.151  0.277±0.119
# CX-P  0.902±0.073  0.621±0.101  0.859±0.102  0.257±0.103  0.223±0.021
# CX-H  0.679±0.186  0.297±0.037  0.455±0.281  0.275±0.166  0.317±0.146
# CX-E  0.804±0.071  0.404±0.158  0.648±0.154  0.223±0.125  0.210±0.055
# CX-A  0.759±0.144  0.382±0.069  0.601±0.236  0.252±0.151  0.277±0.119
# OR    0.811±0.000  0.397±0.234  1.000±0.000  0.134±0.095  0.014±0.000
# IP-P  0.886±0.088  0.614±0.076  0.800±0.195  0.173±0.060  0.202±0.042
# IP-H  0.637±0.132  0.200±0.029  0.333±0.243  0.229±0.092  0.302±0.089
# IP-E  0.715±0.107  0.261±0.059  0.430±0.278  0.169±0.061  0.228±0.048
# IP-A  0.749±0.116  0.339±0.057  0.530±0.261  0.177±0.076  0.247±0.062
# CX-P  0.880±0.091  0.605±0.073  0.764±0.230  0.171±0.060  0.200±0.040
# CX-H  0.644±0.140  0.222±0.023  0.345±0.266  0.238±0.098  0.313±0.086
# CX-E  0.736±0.098  0.284±0.068  0.449±0.277  0.162±0.057  0.214±0.038
# CX-A  0.749±0.116  0.339±0.057  0.530±0.261  0.177±0.076  0.247±0.062
#
#        dataset  target_recall process_type
# OR    CLEF2017            0.9           OR
# IP-P  CLEF2017            0.9           IP
# IP-H  CLEF2017            0.9           IP
# IP-E  CLEF2017            0.9           IP
# IP-A  CLEF2017            0.9           IP
# CX-P  CLEF2017            0.9           CX
# CX-H  CLEF2017            0.9           CX
# CX-E  CLEF2017            0.9           CX
# CX-A  CLEF2017            0.9           CX
# OR    CLEF2018            0.9           OR
# IP-P  CLEF2018            0.9           IP
# IP-H  CLEF2018            0.9           IP
# IP-E  CLEF2018            0.9           IP
# IP-A  CLEF2018            0.9           IP
# CX-P  CLEF2018            0.9           CX
# CX-H  CLEF2018            0.9           CX
# CX-E  CLEF2018            0.9           CX
# CX-A  CLEF2018            0.9           CX
# OR    CLEF2017            0.8           OR
# IP-P  CLEF2017            0.8           IP
# IP-H  CLEF2017            0.8           IP
# IP-E  CLEF2017            0.8           IP
# IP-A  CLEF2017            0.8           IP
# CX-P  CLEF2017            0.8           CX
# CX-H  CLEF2017            0.8           CX
# CX-E  CLEF2017            0.8           CX
# CX-A  CLEF2017            0.8           CX
# OR    CLEF2018            0.8           OR
# IP-P  CLEF2018            0.8           IP
# IP-H  CLEF2018            0.8           IP
# IP-E  CLEF2018            0.8           IP
# IP-A  CLEF2018            0.8           IP
# CX-P  CLEF2018            0.8           CX
# CX-H  CLEF2018            0.8           CX
# CX-E  CLEF2018            0.8           CX
# CX-A  CLEF2018            0.8           CX

# %%
# drop OR rows, keep IP/CX only
df_all_forTTest = df_all_forTTest.drop('OR')
df_all_forTTest
# Out:
#            recall         cost  reliability      loss_er      rel_err  \
# IP-P  0.923±0.054  0.692±0.117  0.840±0.080  0.299±0.115  0.137±0.040
# IP-H  0.699±0.171  0.307±0.050  0.354±0.200  0.261±0.161  0.284±0.162
# IP-E  0.832±0.066  0.444±0.168  0.549±0.123  0.231±0.131  0.164±0.065
# IP-A  0.759±0.144  0.382±0.069  0.457±0.179  0.252±0.151  0.240±0.140
# CX-P  0.919±0.058  0.681±0.113  0.820±0.097  0.291±0.111  0.135±0.038
# CX-H  0.681±0.186  0.304±0.038  0.352±0.215  0.277±0.165  0.305±0.174
# CX-E  0.839±0.066  0.454±0.168  0.561±0.123  0.232±0.131  0.160±0.065
# CX-A  0.759±0.144  0.382±0.069  0.457±0.179  0.252±0.151  0.240±0.140
# IP-P  0.911±0.065  0.684±0.083  0.755±0.165  0.195±0.063  0.127±0.025
# IP-H  0.663±0.136  0.231±0.031  0.245±0.160  0.220±0.096  0.299±0.127
# IP-E  0.769±0.104  0.334±0.087  0.357±0.237  0.156±0.058  0.197±0.083
# IP-A  0.749±0.116  0.339±0.057  0.364±0.188  0.177±0.076  0.232±0.099
# CX-P  0.905±0.069  0.672±0.080  0.712±0.227  0.191±0.062  0.126±0.025
# CX-H  0.649±0.139  0.233±0.025  0.257±0.171  0.239±0.098  0.319±0.128
# CX-E  0.785±0.094  0.353±0.099  0.382±0.248  0.150±0.054  0.181±0.072
# CX-A  0.749±0.116  0.339±0.057  0.364±0.188  0.177±0.076  0.232±0.099
# IP-P  0.908±0.067  0.633±0.108  0.872±0.086  0.265±0.108  0.227±0.024
# IP-H  0.683±0.167  0.286±0.052  0.446±0.258  0.261±0.162  0.298±0.136
# IP-E  0.785±0.076  0.382±0.157  0.604±0.177  0.223±0.122  0.215±0.055
# IP-A  0.759±0.144  0.382±0.069  0.601±0.236  0.252±0.151  0.277±0.119
# CX-P  0.902±0.073  0.621±0.101  0.859±0.102  0.257±0.103  0.223±0.021
# CX-H  0.679±0.186  0.297±0.037  0.455±0.281  0.275±0.166  0.317±0.146
# CX-E  0.804±0.071  0.404±0.158  0.648±0.154  0.223±0.125  0.210±0.055
# CX-A  0.759±0.144  0.382±0.069  0.601±0.236  0.252±0.151  0.277±0.119
# IP-P  0.886±0.088  0.614±0.076  0.800±0.195  0.173±0.060  0.202±0.042
# IP-H  0.637±0.132  0.200±0.029  0.333±0.243  0.229±0.092  0.302±0.089
# IP-E  0.715±0.107  0.261±0.059  0.430±0.278  0.169±0.061  0.228±0.048
# IP-A  0.749±0.116  0.339±0.057  0.530±0.261  0.177±0.076  0.247±0.062
# CX-P  0.880±0.091  0.605±0.073  0.764±0.230  0.171±0.060  0.200±0.040
# CX-H  0.644±0.140  0.222±0.023  0.345±0.266  0.238±0.098  0.313±0.086
# CX-E  0.736±0.098  0.284±0.068  0.449±0.277  0.162±0.057  0.214±0.038
# CX-A  0.749±0.116  0.339±0.057  0.530±0.261  0.177±0.076  0.247±0.062
#
#        dataset  target_recall process_type
# IP-P  CLEF2017            0.9           IP
# IP-H  CLEF2017            0.9           IP
# IP-E  CLEF2017            0.9           IP
# IP-A  CLEF2017            0.9           IP
# CX-P  CLEF2017            0.9           CX
# CX-H  CLEF2017            0.9           CX
# CX-E  CLEF2017            0.9           CX
# CX-A  CLEF2017            0.9           CX
# IP-P  CLEF2018            0.9           IP
# IP-H  CLEF2018            0.9           IP
# IP-E  CLEF2018            0.9           IP
# IP-A  CLEF2018            0.9           IP
# CX-P  CLEF2018            0.9           CX
# CX-H  CLEF2018            0.9           CX
# CX-E  CLEF2018            0.9           CX
# CX-A  CLEF2018            0.9           CX
# IP-P  CLEF2017            0.8           IP
# IP-H  CLEF2017            0.8           IP
# IP-E  CLEF2017            0.8           IP
# IP-A  CLEF2017            0.8           IP
# CX-P  CLEF2017            0.8           CX
# CX-H  CLEF2017            0.8           CX
# CX-E  CLEF2017            0.8           CX
# CX-A  CLEF2017            0.8           CX
# IP-P  CLEF2018            0.8           IP
# IP-H  CLEF2018            0.8           IP
# IP-E  CLEF2018            0.8           IP
# IP-A  CLEF2018            0.8           IP
# CX-P  CLEF2018            0.8           CX
# CX-H  CLEF2018            0.8           CX
# CX-E  CLEF2018            0.8           CX
# CX-A  CLEF2018            0.8           CX

# %%
eval_measures = ['recall', 'cost', 'reliability', 'loss_er','rel_err']
for eval_measure in eval_measures:
  df_all_forTTest[eval_measure] = df_all_forTTest[eval_measure].replace('±0.[0-9]+','', regex=True).astype(float)
  
df_all_forTTest
# Out:
#       recall   cost  reliability  loss_er  rel_err   dataset  target_recall  \
# IP-P   0.923  0.692        0.840    0.299    0.137  CLEF2017            0.9
# IP-H   0.699  0.307        0.354    0.261    0.284  CLEF2017            0.9
# IP-E   0.832  0.444        0.549    0.231    0.164  CLEF2017            0.9
# IP-A   0.759  0.382        0.457    0.252    0.240  CLEF2017            0.9
# CX-P   0.919  0.681        0.820    0.291    0.135  CLEF2017            0.9
# CX-H   0.681  0.304        0.352    0.277    0.305  CLEF2017            0.9
# CX-E   0.839  0.454        0.561    0.232    0.160  CLEF2017            0.9
# CX-A   0.759  0.382        0.457    0.252    0.240  CLEF2017            0.9
# IP-P   0.911  0.684        0.755    0.195    0.127  CLEF2018            0.9
# IP-H   0.663  0.231        0.245    0.220    0.299  CLEF2018            0.9
# IP-E   0.769  0.334        0.357    0.156    0.197  CLEF2018            0.9
# IP-A   0.749  0.339        0.364    0.177    0.232  CLEF2018            0.9
# CX-P   0.905  0.672        0.712    0.191    0.126  CLEF2018            0.9
# CX-H   0.649  0.233        0.257    0.239    0.319  CLEF2018            0.9
# CX-E   0.785  0.353        0.382    0.150    0.181  CLEF2018            0.9
# CX-A   0.749  0.339        0.364    0.177    0.232  CLEF2018            0.9
# IP-P   0.908  0.633        0.872    0.265    0.227  CLEF2017            0.8
# IP-H   0.683  0.286        0.446    0.261    0.298  CLEF2017            0.8
# IP-E   0.785  0.382        0.604    0.223    0.215  CLEF2017            0.8
# IP-A   0.759  0.382        0.601    0.252    0.277  CLEF2017            0.8
# CX-P   0.902  0.621        0.859    0.257    0.223  CLEF2017            0.8
# CX-H   0.679  0.297        0.455    0.275    0.317  CLEF2017            0.8
# CX-E   0.804  0.404        0.648    0.223    0.210  CLEF2017            0.8
# CX-A   0.759  0.382        0.601    0.252    0.277  CLEF2017            0.8
# IP-P   0.886  0.614        0.800    0.173    0.202  CLEF2018            0.8
# IP-H   0.637  0.200        0.333    0.229    0.302  CLEF2018            0.8
# IP-E   0.715  0.261        0.430    0.169    0.228  CLEF2018            0.8
# IP-A   0.749  0.339        0.530    0.177    0.247  CLEF2018            0.8
# CX-P   0.880  0.605        0.764    0.171    0.200  CLEF2018            0.8
# CX-H   0.644  0.222        0.345    0.238    0.313  CLEF2018            0.8
# CX-E   0.736  0.284        0.449    0.162    0.214  CLEF2018            0.8
# CX-A   0.749  0.339        0.530    0.177    0.247  CLEF2018            0.8
#
#      process_type
# IP-P           IP
# IP-H           IP
# IP-E           IP
# IP-A           IP
# CX-P           CX
# CX-H           CX
# CX-E           CX
# CX-A           CX
# IP-P           IP
# IP-H           IP
# IP-E           IP
# IP-A           IP
# CX-P           CX
# CX-H           CX
# CX-E           CX
# CX-A           CX
# IP-P           IP
# IP-H           IP
# IP-E           IP
# IP-A           IP
# CX-P           CX
# CX-H           CX
# CX-E           CX
# CX-A           CX
# IP-P           IP
# IP-H           IP
# IP-E           IP
# IP-A           IP
# CX-P           CX
# CX-H           CX
# CX-E           CX
# CX-A           CX

# %%
df_all_forTTest.to_csv(DIR_runs+'TTest/results/all_runs_scores_forTTest.csv')

# %% [markdown]
# ## Paired T-Test for Multiple Runs
#
# Below are the T-Test results for all runs (rankings) on CLEF2017 and CLEF2018, from the p-values, we can prove that the mean difference between IP and CX are not statistically significant (> 0.05) for all measures: recall, reliability, cost, loss error , and  rel error.
# So from this observation, and since the CX method is more computationally expensive, we can select IP among CX.

# %% [markdown]
# ### T-Test for all target recalls

# %%
eval_measures = ['recall', 'cost', 'reliability', 'loss_er','rel_err']
for eval_measure in eval_measures:
    statistic, pvalue = stats.ttest_rel(df_all_forTTest.loc[df_all_forTTest['process_type'] == 'IP'][eval_measure], df_all_forTTest.loc[df_all_forTTest['process_type'] == 'CX'][eval_measure])
    print(f'{eval_measure: <15}: statistic=\t{statistic: <20}\t pvalue= {pvalue}')
# Out:
# recall         : statistic=	-0.27333031884273906	 pvalue= 0.7883268194663388
# cost           : statistic=	-1.240529405510299  	 pvalue= 0.2338334817885967
# reliability    : statistic=	-0.21786183154324476	 pvalue= 0.8304727512810973
# loss_er        : statistic=	-0.7032108464077429 	 pvalue= 0.4926955922828904
# rel_err        : statistic=	-0.52374726457658   	 pvalue= 0.6081064659372762

# %% [markdown]
# ### T-Test for each target recall

# %%
des_recalls = [0.9, 0.8]
eval_measures = ['recall', 'cost', 'reliability', 'loss_er','rel_err']
for des_recall in des_recalls:
  for eval_measure in eval_measures:
    statistic, pvalue = stats.ttest_rel(df_all_forTTest.loc[df_all_forTTest['process_type'] == 'IP'][eval_measure], df_all_forTTest.loc[df_all_forTTest['process_type'] == 'CX'][eval_measure])
    print(f'{des_recall}_{eval_measure: <15}: statistic=\t{statistic: <20}\t pvalue= {pvalue}')
  print('-----------------------------------------------------------------------------------')
    #print(des_recall, eval_measure, stats.ttest_rel(df_all_IP.loc[df_all_IP['des_recall'] == des_recall][eval_measure], df_all_CX.loc[df_all_CX['des_recall'] == des_recall][eval_measure]))
# Out:
# 0.9_recall         : statistic=	-0.27333031884273906	 pvalue= 0.7883268194663388
# 0.9_cost           : statistic=	-1.240529405510299  	 pvalue= 0.2338334817885967
# 0.9_reliability    : statistic=	-0.21786183154324476	 pvalue= 0.8304727512810973
# 0.9_loss_er        : statistic=	-0.7032108464077429 	 pvalue= 0.4926955922828904
# 0.9_rel_err        : statistic=	-0.52374726457658   	 pvalue= 0.6081064659372762
# -----------------------------------------------------------------------------------
# 0.8_recall         : statistic=	-0.27333031884273906	 pvalue= 0.7883268194663388
# 0.8_cost           : statistic=	-1.240529405510299  	 pvalue= 0.2338334817885967
# 0.8_reliability    : statistic=	-0.21786183154324476	 pvalue= 0.8304727512810973
# 0.8_loss_er        : statistic=	-0.7032108464077429 	 pvalue= 0.4926955922828904
# 0.8_rel_err        : statistic=	-0.52374726457658   	 pvalue= 0.6081064659372762
# -----------------------------------------------------------------------------------
